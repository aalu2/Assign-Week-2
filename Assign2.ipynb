# %%
#Answer of 1
def check_even_odd(n):
  if n % 2 == 0:
    print("Even")
  if n % 2 == 1:
    print("Odd")
check_even_odd(10)  
def check_even_odd(n):
  if n % 2 == 0:
    print("Even")
  if n % 2 == 1:
    print("Odd")
check_even_odd(11)
# Out:
# Even
# Odd

# %%
#Answer of 2
def number(n):
  for i in range(n-1,0,-1):
    if i % 2 == 1:
      print(i)
number(13)
# Out:
# 11
# 9
# 7
# 5
# 3
# 1

# %%
#Answer of 3
def number(n):
  add = 0
  for i in range(1,n+1):
    if i % 2 == 1:
      add += i
  print(add)
number(7)
def number(n):
  add = 0
  for i in range(1,n+1):
    if i % 2 == 1:
      add += i
  print(add)
number(6)
# Out:
# 16
# 9

# %%
#Answer of 4
def number(n):
  add = 0
  for i in range(1,n+1):
    if i % 2 == 0:
      add += i
  print(add)
number(6)
# Out:
# 12

# %%
#Answer of 5
def enter_positive_only(n):
  if n > 0 and n % 2 == 0:
    for i in range (n,-1,-2):
      print(i,end=" ")
  if n > 0 and n % 2 == 1:
    for i in range(n,int(n/2),-2):
      print(i,end=" ")
enter_positive_only(19)
# Out:
# 19 17 15 13 11

# %%
#Answer of 6
def small2_sqrsum(a,b,c):
    x = max(a,b,c)
    return (a*a + b*b + c*c) - (x*x) 
#Test
print(small2_sqrsum(1,2,3))
print(small2_sqrsum(-3,1,5))
# Out:
# 5
# 10
